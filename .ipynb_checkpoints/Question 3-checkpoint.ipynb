# %%
import pandas as pd
import numpy as np
import math
import string
import nltk 
import re
from nltk import word_tokenize 
from sklearn.feature_extraction.text import TfidfVectorizer 
from nltk.stem import WordNetLemmatizer,SnowballStemmer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt 
from nltk.collocations import BigramCollocationFinder 
from nltk.metrics import BigramAssocMeasures
from collections import Counter
from nltk.util import ngrams

# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')

# %%
# Reading the text from text file and make a dataframe
l_col1 = []
with open("data/text.txt","r") as file:
    lines = file.readlines()
    for ind, line in enumerate(lines[:-1]):
        l_col1.append(line)
df= pd.DataFrame({'sentences': l_col1})
df
# Out:
#                                             sentences
# 0   As a term, data analytics predominantly refers...
# 1   intelligence (BI), reporting and online analyt...
# 2   analytics.In that sense, it's similar in natur...
# 3   approaches to analyzing data --with the differ...
# 4   data analytics has a broader focus. The expans...
# 5   cases, people use data analytics specifically ...
# 6   category.  Data analytics initiatives can help...
# 7   efficiency, optimize marketing campaigns and c...
# 8   emerging market trends and gain a competitive ...
# 9   boosting business performance. Depending on th...
# 10  can consist of either historical records or ne...
# 11  analytics uses. In addition, it can come from ...
# 12  a high level, data analytics methodologies inc...
# 13  patterns and relationships in data, and confir...
# 14  techniques to determine whether hypotheses abo...
# 15  compared to detective work, while CDA is akin ...
# 16  distinction first drawn by statistician John W...
# 17  analytics can also be separated into quantitat...
# 18  former involves analysis of numerical data wit...
# 19  measured statistically. The qualitative approa...
# 20  the content of non-numerical data like text, i...

# %%
# Apply first round of text cleaning techniques
def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    #get rid of non english charectors
    text = re.sub("([^\x00-\x7F])+","",text)
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
# Let's take a look at the updated text
df['CleanedSentences'] = pd.DataFrame(df['sentences'].apply(round1))
df
# Out:
#                                             sentences  \
# 0   As a term, data analytics predominantly refers...
# 1   intelligence (BI), reporting and online analyt...
# 2   analytics.In that sense, it's similar in natur...
# 3   approaches to analyzing data --with the differ...
# 4   data analytics has a broader focus. The expans...
# 5   cases, people use data analytics specifically ...
# 6   category.  Data analytics initiatives can help...
# 7   efficiency, optimize marketing campaigns and c...
# 8   emerging market trends and gain a competitive ...
# 9   boosting business performance. Depending on th...
# 10  can consist of either historical records or ne...
# 11  analytics uses. In addition, it can come from ...
# 12  a high level, data analytics methodologies inc...
# 13  patterns and relationships in data, and confir...
# 14  techniques to determine whether hypotheses abo...
# 15  compared to detective work, while CDA is akin ...
# 16  distinction first drawn by statistician John W...
# 17  analytics can also be separated into quantitat...
# 18  former involves analysis of numerical data wit...
# 19  measured statistically. The qualitative approa...
# 20  the content of non-numerical data like text, i...
#
#                                      CleanedSentences
# 0   as a term data analytics predominantly refers ...
# 1   intelligence bi reporting and online analytica...
# 2   analyticsin that sense its similar in nature t...
# 3   approaches to analyzing data with the differen...
# 4   data analytics has a broader focus the expansi...
# 5   cases people use data analytics specifically t...
# 6   category  data analytics initiatives can help ...
# 7   efficiency optimize marketing campaigns and cu...
# 8   emerging market trends and gain a competitive ...
# 9   boosting business performance depending on the...
# 10  can consist of either historical records or ne...
# 11  analytics uses in addition it can come from a ...
# 12  a high level data analytics methodologies incl...
# 13  patterns and relationships in data and confirm...
# 14  techniques to determine whether hypotheses abo...
# 15  compared to detective work while cda is akin t...
# 16  distinction first drawn by statistician john w...
# 17  analytics can also be separated into quantitat...
# 18  former involves analysis of numerical data wit...
# 19  measured statistically the qualitative approac...
# 20  the content of nonnumerical data like text ima...

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

#tokenizing and removing stop words
stop_words = set(stopwords.words('english')) 
for i in df.index:
    word_tokens = word_tokenize(df['CleanedSentences'][i])
    df['CleanedSentences'][i] = [w for w in word_tokens if not w in stop_words] 
    
df.head()
# Out:
#                                            sentences  \
# 0  As a term, data analytics predominantly refers...
# 1  intelligence (BI), reporting and online analyt...
# 2  analytics.In that sense, it's similar in natur...
# 3  approaches to analyzing data --with the differ...
# 4  data analytics has a broader focus. The expans...
#
#                                     CleanedSentences
# 0  [term, data, analytics, predominantly, refers,...
# 1  [intelligence, bi, reporting, online, analytic...
# 2  [analyticsin, sense, similar, nature, business...
# 3  [approaches, analyzing, data, difference, latt...
# 4  [data, analytics, broader, focus, expansive, v...

# %%
#  using nltk WordNetLemmatizer function to normalize the tweets
# Text Normalization -reducing terms to their base word(like runs, run, running, ran to base word run)
lemmatizer = WordNetLemmatizer()
df['CleanedSentences'] = df['CleanedSentences'].apply(lambda x: [lemmatizer.lemmatize(i) for i in x])


for i in range(len(df['CleanedSentences'])):
    df['CleanedSentences'][i] = ' '.join(df['CleanedSentences'][i])    

df.head()
# Out:
#                                            sentences  \
# 0  As a term, data analytics predominantly refers...
# 1  intelligence (BI), reporting and online analyt...
# 2  analytics.In that sense, it's similar in natur...
# 3  approaches to analyzing data --with the differ...
# 4  data analytics has a broader focus. The expans...
#
#                                     CleanedSentences
# 0  term data analytics predominantly refers assor...
# 1  intelligence bi reporting online analytical pr...
# 2  analyticsin sense similar nature business anal...
# 3  approach analyzing data difference latter orie...
# 4  data analytics broader focus expansive view te...

# %%
#create a new column for tokens
df['tokenizedWords'] = df['CleanedSentences'].apply(lambda x: x.split())

# %%
# count the number of words in each doc
word_count_list = np.zeros(df.shape[0], dtype=np.int)
doc_list = df['CleanedSentences'].values
for i in df.index:
    word_count_list[i] = len(doc_list[i].split())

# add the word count as a new column
df['word_count'] = word_count_list

df.head()
# Out:
#                                            sentences  \
# 0  As a term, data analytics predominantly refers...
# 1  intelligence (BI), reporting and online analyt...
# 2  analytics.In that sense, it's similar in natur...
# 3  approaches to analyzing data --with the differ...
# 4  data analytics has a broader focus. The expans...
#
#                                     CleanedSentences  \
# 0  term data analytics predominantly refers assor...
# 1  intelligence bi reporting online analytical pr...
# 2  analyticsin sense similar nature business anal...
# 3  approach analyzing data difference latter orie...
# 4  data analytics broader focus expansive view te...
#
#                                       tokenizedWords  word_count
# 0  [term, data, analytics, predominantly, refers,...           9
# 1  [intelligence, bi, reporting, online, analytic...          10
# 2  [analyticsin, sense, similar, nature, business...           9
# 3  [approach, analyzing, data, difference, latter...           8
# 4  [data, analytics, broader, focus, expansive, v...          10

# %%
def word_count_Line(df):
    temp = []
    for l in df.CleanedSentences.values:
        counts = dict()
        words = l.split()

        for word in words:
            if word in counts:
                counts[word] += 1
            else:
                counts[word] = 1
        temp.append(counts)  
    df['word_count_line']=temp

# %%
word_count_Line(df)

# %%
def word_prob(df,col,word):
    i = 0
    p = 0
    for my_dict in df[col]:
        for k,v in my_dict.items():
            if k == word:
                p = (v/df['word_count'][i])
        print("Probability of the '{0}' occuring in line {1} is {2}".format(word,i,p))
        p = 0
        i = i+1

# %%
word_prob(df,'word_count_line','data')
# Out:
# Probability of the 'data' occuring in line 0 is 0.1111111111111111
# Probability of the 'data' occuring in line 1 is 0
# Probability of the 'data' occuring in line 2 is 0
# Probability of the 'data' occuring in line 3 is 0.125
# Probability of the 'data' occuring in line 4 is 0.1
# Probability of the 'data' occuring in line 5 is 0.08333333333333333
# Probability of the 'data' occuring in line 6 is 0.1
# Probability of the 'data' occuring in line 7 is 0
# Probability of the 'data' occuring in line 8 is 0
# Probability of the 'data' occuring in line 9 is 0.1111111111111111
# Probability of the 'data' occuring in line 10 is 0
# Probability of the 'data' occuring in line 11 is 0.1
# Probability of the 'data' occuring in line 12 is 0.16666666666666666
# Probability of the 'data' occuring in line 13 is 0.2222222222222222
# Probability of the 'data' occuring in line 14 is 0.1
# Probability of the 'data' occuring in line 15 is 0
# Probability of the 'data' occuring in line 16 is 0.16666666666666666
# Probability of the 'data' occuring in line 17 is 0.2222222222222222
# Probability of the 'data' occuring in line 18 is 0.125
# Probability of the 'data' occuring in line 19 is 0
# Probability of the 'data' occuring in line 20 is 0.09090909090909091

# %% [markdown]
# ### A. Above function shows the probability of word 'data' appearing in each line

# %%
# make a new df to store words
columns=['text_index', 'word']
word_df = pd.DataFrame(columns=columns)
# convert df to array to improve loop time performance
words = df['tokenizedWords'].values
    
for i in df.index:
    temp = [[str(i), w] for w in words[i]]
    temp_df = pd.DataFrame(temp, columns=columns)
    # add 1 row for each word
    word_df = word_df.append(temp_df, ignore_index=True)
    
word_df.head()
# Out:
#   text_index           word
# 0          0           term
# 1          0           data
# 2          0      analytics
# 3          0  predominantly
# 4          0         refers

# %%
# function to find the most frequent values in a column and their frequencies
from collections import Counter
def most_commons(df, cl_name):
    return pd.DataFrame(Counter(df[cl_name]).most_common(), columns=[cl_name, 'frequency'])

# top most frequently mentioned named entities
(most_commons(word_df, 'word')).head()
# Out:
#         word  frequency
# 0       data         18
# 1  analytics          9
# 2   analysis          6
# 3   business          5
# 4       term          3

# %% [markdown]
# Table above shows the top 5 words appear the most in the text with their respective frequency.

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

def barchart_words(word_df,title):
    
    temp_word = word_df.word.tolist()
    temp_freq = word_df.frequency.tolist()

    y_pos = np.arange(len(temp_word))

    plt.barh(y_pos, temp_freq, align='center', alpha=0.5 , 
             color=['black', 'red', 'green', 'blue', 'cyan','magenta','yellow','Purple','orange','Brown'])
    plt.yticks(y_pos, temp_word)
    plt.xlabel('count')
    plt.title(title)

    plt.show()

# %%
barchart_words((most_commons(word_df, 'word')).head(),'Top 5 words repeated in this text')

# %%
# plot word cloud of a given text
from wordcloud import WordCloud, STOPWORDS
def plot_word_cloud(df, colormap='bwr', title=None, width=1000, height=800):
    # set the stop words
    stopwords = set(STOPWORDS)
    Additional_stop_words = ['']
    words = (' '.join(df['word'])).lower()
    for s in  Additional_stop_words:
        stopwords.add(s)
        
    # generate WordCloud
    if type(words)==str:
        wc = WordCloud(background_color="white", stopwords=stopwords, 
                       width=width, height=height, colormap=colormap).generate(words)
    # for simplicity, I assume that if words is not an string, it is a dictionary of word frequencies
    else:
        wc = WordCloud(background_color="white", stopwords=stopwords, 
                       width=width, height=height, colormap=colormap).generate_from_frequencies(words)

    # show the WordCloud
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    if title:
        plt.title(title, fontsize=25, y=1.01)

# %%
plot_word_cloud(word_df)

# %% [markdown]
# Wordcloud above shows the popularity distributions of each word in the text.

# %%
temp_df = most_commons(word_df, 'word')
print(temp_df.shape)
temp_df.head(153)
# Out:
# (153, 2)
#           word  frequency
# 0         data         18
# 1    analytics          9
# 2     analysis          6
# 3     business          5
# 4         term          3
# ..         ...        ...
# 148      audio          1
# 149      video          1
# 150  including          1
# 151     common          1
# 152     phrase          1
#
# [153 rows x 2 columns]

# %% [markdown]
# ### b. There are 153 distinct words in this text

# %%
temp = most_commons(word_df, 'word')
# temp.word[0]
for i in temp.index:
    print("Probability of the '{0}' occuring in text {1}".format(temp.word[i],temp.frequency[i]/temp.shape[0]))
# Out:
# Probability of the 'data' occuring in text 0.11764705882352941
# Probability of the 'analytics' occuring in text 0.058823529411764705
# Probability of the 'analysis' occuring in text 0.0392156862745098
# Probability of the 'business' occuring in text 0.032679738562091505
# Probability of the 'term' occuring in text 0.0196078431372549
# Probability of the 'application' occuring in text 0.013071895424836602
# Probability of the 'bi' occuring in text 0.013071895424836602
# Probability of the 'advanced' occuring in text 0.013071895424836602
# Probability of the 'approach' occuring in text 0.013071895424836602
# Probability of the 'us' occuring in text 0.013071895424836602
# Probability of the 'focus' occuring in text 0.013071895424836602
# Probability of the 'exploratory' occuring in text 0.013071895424836602
# Probability of the 'eda' occuring in text 0.013071895424836602
# Probability of the 'cda' occuring in text 0.013071895424836602
# Probability of the 'compared' occuring in text 0.013071895424836602
# Probability of the 'work' occuring in text 0.013071895424836602
# Probability of the 'qualitative' occuring in text 0.013071895424836602
# Probability of the 'predominantly' occuring in text 0.006535947712418301
# Probability of the 'refers' occuring in text 0.006535947712418301
# Probability of the 'assortment' occuring in text 0.006535947712418301
# Probability of the 'basic' occuring in text 0.006535947712418301
# Probability of the 'intelligence' occuring in text 0.006535947712418301
# Probability of the 'reporting' occuring in text 0.006535947712418301
# Probability of the 'online' occuring in text 0.006535947712418301
# Probability of the 'analytical' occuring in text 0.006535947712418301
# Probability of the 'processing' occuring in text 0.006535947712418301
# Probability of the 'olap' occuring in text 0.006535947712418301
# Probability of the 'various' occuring in text 0.006535947712418301
# Probability of the 'form' occuring in text 0.006535947712418301
# Probability of the 'analyticsin' occuring in text 0.006535947712418301
# Probability of the 'sense' occuring in text 0.006535947712418301
# Probability of the 'similar' occuring in text 0.006535947712418301
# Probability of the 'nature' occuring in text 0.006535947712418301
# Probability of the 'another' occuring in text 0.006535947712418301
# Probability of the 'umbrella' occuring in text 0.006535947712418301
# Probability of the 'analyzing' occuring in text 0.006535947712418301
# Probability of the 'difference' occuring in text 0.006535947712418301
# Probability of the 'latter' occuring in text 0.006535947712418301
# Probability of the 'oriented' occuring in text 0.006535947712418301
# Probability of the 'broader' occuring in text 0.006535947712418301
# Probability of the 'expansive' occuring in text 0.006535947712418301
# Probability of the 'view' occuring in text 0.006535947712418301
# Probability of the 'isnt' occuring in text 0.006535947712418301
# Probability of the 'universal' occuring in text 0.006535947712418301
# Probability of the 'though' occuring in text 0.006535947712418301
# Probability of the 'case' occuring in text 0.006535947712418301
# Probability of the 'people' occuring in text 0.006535947712418301
# Probability of the 'use' occuring in text 0.006535947712418301
# Probability of the 'specifically' occuring in text 0.006535947712418301
# Probability of the 'mean' occuring in text 0.006535947712418301
# Probability of the 'treating' occuring in text 0.006535947712418301
# Probability of the 'separate' occuring in text 0.006535947712418301
# Probability of the 'category' occuring in text 0.006535947712418301
# Probability of the 'initiative' occuring in text 0.006535947712418301
# Probability of the 'help' occuring in text 0.006535947712418301
# Probability of the 'increase' occuring in text 0.006535947712418301
# Probability of the 'revenue' occuring in text 0.006535947712418301
# Probability of the 'improve' occuring in text 0.006535947712418301
# Probability of the 'operational' occuring in text 0.006535947712418301
# Probability of the 'efficiency' occuring in text 0.006535947712418301
# Probability of the 'optimize' occuring in text 0.006535947712418301
# Probability of the 'marketing' occuring in text 0.006535947712418301
# Probability of the 'campaign' occuring in text 0.006535947712418301
# Probability of the 'customer' occuring in text 0.006535947712418301
# Probability of the 'service' occuring in text 0.006535947712418301
# Probability of the 'effort' occuring in text 0.006535947712418301
# Probability of the 'respond' occuring in text 0.006535947712418301
# Probability of the 'quickly' occuring in text 0.006535947712418301
# Probability of the 'emerging' occuring in text 0.006535947712418301
# Probability of the 'market' occuring in text 0.006535947712418301
# Probability of the 'trend' occuring in text 0.006535947712418301
# Probability of the 'gain' occuring in text 0.006535947712418301
# Probability of the 'competitive' occuring in text 0.006535947712418301
# Probability of the 'edge' occuring in text 0.006535947712418301
# Probability of the 'rival' occuring in text 0.006535947712418301
# Probability of the 'ultimate' occuring in text 0.006535947712418301
# Probability of the 'goal' occuring in text 0.006535947712418301
# Probability of the 'boosting' occuring in text 0.006535947712418301
# Probability of the 'performance' occuring in text 0.006535947712418301
# Probability of the 'depending' occuring in text 0.006535947712418301
# Probability of the 'particular' occuring in text 0.006535947712418301
# Probability of the 'thats' occuring in text 0.006535947712418301
# Probability of the 'analyzed' occuring in text 0.006535947712418301
# Probability of the 'consist' occuring in text 0.006535947712418301
# Probability of the 'either' occuring in text 0.006535947712418301
# Probability of the 'historical' occuring in text 0.006535947712418301
# Probability of the 'record' occuring in text 0.006535947712418301
# Probability of the 'new' occuring in text 0.006535947712418301
# Probability of the 'information' occuring in text 0.006535947712418301
# Probability of the 'processed' occuring in text 0.006535947712418301
# Probability of the 'realtime' occuring in text 0.006535947712418301
# Probability of the 'addition' occuring in text 0.006535947712418301
# Probability of the 'come' occuring in text 0.006535947712418301
# Probability of the 'mix' occuring in text 0.006535947712418301
# Probability of the 'internal' occuring in text 0.006535947712418301
# Probability of the 'system' occuring in text 0.006535947712418301
# Probability of the 'external' occuring in text 0.006535947712418301
# Probability of the 'source' occuring in text 0.006535947712418301
# Probability of the 'high' occuring in text 0.006535947712418301
# Probability of the 'level' occuring in text 0.006535947712418301
# Probability of the 'methodology' occuring in text 0.006535947712418301
# Probability of the 'include' occuring in text 0.006535947712418301
# Probability of the 'aim' occuring in text 0.006535947712418301
# Probability of the 'find' occuring in text 0.006535947712418301
# Probability of the 'pattern' occuring in text 0.006535947712418301
# Probability of the 'relationship' occuring in text 0.006535947712418301
# Probability of the 'confirmatory' occuring in text 0.006535947712418301
# Probability of the 'applies' occuring in text 0.006535947712418301
# Probability of the 'statistical' occuring in text 0.006535947712418301
# Probability of the 'technique' occuring in text 0.006535947712418301
# Probability of the 'determine' occuring in text 0.006535947712418301
# Probability of the 'whether' occuring in text 0.006535947712418301
# Probability of the 'hypothesis' occuring in text 0.006535947712418301
# Probability of the 'set' occuring in text 0.006535947712418301
# Probability of the 'true' occuring in text 0.006535947712418301
# Probability of the 'false' occuring in text 0.006535947712418301
# Probability of the 'often' occuring in text 0.006535947712418301
# Probability of the 'detective' occuring in text 0.006535947712418301
# Probability of the 'akin' occuring in text 0.006535947712418301
# Probability of the 'judge' occuring in text 0.006535947712418301
# Probability of the 'jury' occuring in text 0.006535947712418301
# Probability of the 'court' occuring in text 0.006535947712418301
# Probability of the 'trial' occuring in text 0.006535947712418301
# Probability of the 'distinction' occuring in text 0.006535947712418301
# Probability of the 'first' occuring in text 0.006535947712418301
# Probability of the 'drawn' occuring in text 0.006535947712418301
# Probability of the 'statistician' occuring in text 0.006535947712418301
# Probability of the 'john' occuring in text 0.006535947712418301
# Probability of the 'w' occuring in text 0.006535947712418301
# Probability of the 'tukey' occuring in text 0.006535947712418301
# Probability of the 'book' occuring in text 0.006535947712418301
# Probability of the 'also' occuring in text 0.006535947712418301
# Probability of the 'separated' occuring in text 0.006535947712418301
# Probability of the 'quantitative' occuring in text 0.006535947712418301
# Probability of the 'former' occuring in text 0.006535947712418301
# Probability of the 'involves' occuring in text 0.006535947712418301
# Probability of the 'numerical' occuring in text 0.006535947712418301
# Probability of the 'quantifiable' occuring in text 0.006535947712418301
# Probability of the 'variable' occuring in text 0.006535947712418301
# Probability of the 'measured' occuring in text 0.006535947712418301
# Probability of the 'statistically' occuring in text 0.006535947712418301
# Probability of the 'interpretive' occuring in text 0.006535947712418301
# Probability of the 'understanding' occuring in text 0.006535947712418301
# Probability of the 'content' occuring in text 0.006535947712418301
# Probability of the 'nonnumerical' occuring in text 0.006535947712418301
# Probability of the 'like' occuring in text 0.006535947712418301
# Probability of the 'text' occuring in text 0.006535947712418301
# Probability of the 'image' occuring in text 0.006535947712418301
# Probability of the 'audio' occuring in text 0.006535947712418301
# Probability of the 'video' occuring in text 0.006535947712418301
# Probability of the 'including' occuring in text 0.006535947712418301
# Probability of the 'common' occuring in text 0.006535947712418301
# Probability of the 'phrase' occuring in text 0.006535947712418301

# %%
def getNGrams(wordlist, n):
    ng = []
    for i in range(len(wordlist)-(n-1)):
        ng.append(wordlist[i:i+n])
    return ng

def NGramsFlatList(df):
    ng = []
    flat_list = []
    for i in df.index:
        a = getNGrams(df['tokenizedWords'][i],2)
        ng.append(a)
    for sublist in ng:
        for item in sublist:
            flat_list.append(item)
    return flat_list

# %%
def twoWords(df,word_df,First,Second):
    fl = NGramsFlatList(df)
    noOccurance = fl.count([First,Second])
    FirstWordOccurance = ((word_df[word_df['word'] == First]).count()).word
    print("Probability of word '{0}' occuring after word '{1}' is: {2}".format(First,Second,(noOccurance/FirstWordOccurance)))

# %%
twoWords(df,word_df,'data','analytics')
# Out:
# Probability of word 'data' occuring after word 'analytics' is: 0.2777777777777778

# %% [markdown]
# ### c. Probability of word 'data' occuring after word 'analytics' is: 0.2777777777777778
